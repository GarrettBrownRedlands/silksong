# %% [markdown]
# ## Introduction to Data Science
#
# #### University of Redlands - DATA 101
# #### Prof: Joanna Bieri [joanna_bieri@redlands.edu](mailto:joanna_bieri@redlands.edu)
# #### [Class Website: data101.joannabieri.com](https://joannabieri.com/data101.html)
#
# ---------------------------------------
# # Homework Day 13
# ---------------------------------------
#
# GOALS:
#
# 1. Explore and respond to ideas around data ethics
# 2. Recreate other peoples work to more honestly reflect data.
#
# ----------------------------------------------------------
#
# This homework has **4 questions** and **1 exercise**

# %% [markdown]
# ## Important Information
#
# - Email: [joanna_bieri@redlands.edu](mailto:joanna_bieri@redlands.edu)
# - Office Hours: Duke 209 <a href="https://joannabieri.com/schedule.html"> Click Here for Joanna's Schedule</a>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.io as pio
pio.renderers.defaule = 'colab'

from itables import show

# This stops a few warning messages from showing
pd.options.mode.chained_assignment = None 
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## Data Science Ethics
#
# ## Misrepresentation
#
# Misrepresentation can happen intentionally or unintentionally. It can arise because of lack of knowledge of competence in data science. It is important to be aware of misrepresentation and be able to spot it a mile away in your work and in other peoples work!
#
# What is wrong with this picture? How would you correct it?
#
#
# ![Confirmed Covid Cases](images/ga-dph-declining-bars.jpg)
#
# - Overall this looks like the heights of bars are going down.
# - Dates are on the x-axis.
# - Are covid cases going down over time?
#
# **Q1** Write in your own words what you see that is wrong with this graph. What is the story it is telling vs the real story in the data?
#
# The graph is misleading with how it doesn't show an accurate timeline. It has the dates sorted by total case numbers rather than linearly by the date of the sample. It portrays a timeline where covid cases are going down whereas that isn't actually the case.
#
#
# **Q2** Is it okay to misrepresent your data if you are getting people to "do the right thing"? For example, more exercise is good for you, right? Was it so bad to misrepresent the results of the cancer and exercise studies?
#
# It's always going to be a gray area. That's the nature of ethics. For the example given, I'd say yes. However, when everything is subjective, most data really only serves to get a point across or portray a specific narrative that someone else has curated.

# %% [markdown]
# ## Data Privacy
#
# The question of data privacy is complicated and rests on the idea of what amount of expected privacy are we entitled to when we put our data online.
#
# ## Data Privacy -  Case study:
#
# **Q3** When analyzing data that is publicly shared, how can you make sure that you are not violating a persons reasonable expectation of privacy? What do you think the rules should be here? How would you want your data treated?
#
# By avoiding matching a profile to a specific person or another form of individualized identification, you aren't ever drawing a connection between a set of data points that make up one person to having a profile of a person's characteristics. I think that personally data should be purely opt-in only, however unfortunately with our society we've resigned ourselves to giving up our data in exchange for access to the internet. Personally, I wouldn't want my data linked to who I am as a person.
#
# **Q4** Does the answer to the question "Should I scrape this data" vary based on what the data is about? Give two examples where the answer might be different.
#
# Yes, the answer varies. For instance, if the data contains the results of the effectiveness of a new medication? Go for it! If the data also contains the personal information of every person who participated in the study? Maybe not!

# %% [markdown]
# ## Exercise 1
#
# Consider the following visualization that was shared on Twitter:
#
# Originally from: https://twitter.com/JonBoeckenstedt/status/1291602888376999936
#
# ![Masks v. No Masks](images/masks-v-nomasks.png)
#
# You are going to construct the data by reading (approximate is okay) the numbers from the picture.
#
# 1. What is most misleading about this graph - essay answer
#
# The most misleading thing about the graph is how it represents two different data sets at the same y level on the graph but corresponding to different values based on which type it is.
#
# 2.  Create a data frame that can be used to re-construct this visualization. You may need to guess some of the numbers, that's ok. You should first think about how many rows and columns you'll need and what you want to call your variables.
#
#
# Here is some code to get you started:

# %%
# Literally read the x, y numbers and enter them into a pandas dataframe. Then re-do the graph.

# Dates from the x-axis
date = ['7/12/2020', '7/13/2020', '7/14/2020', '7/15/2020', '7/16/2020', '7/17/2020', '7/18/2020', '7/19/2020', '7/20/2020', '7/21/2020', '7/22/2020', '7/23/2020', '7/24/2020', '7/25/2020', '7/26/2020', '7/27/2020', '7/28/2020', '7/29/2020', '7/30/2020', '7/31/2020', '8/1/2020', '8/2/2020', '8/3/2020']
# Numbers for mask data line y-axis LEFT SIDE
count_mask = [25.3, 19.7, 19.6, 20.5, 19.8, 19.8, 20.5, 20.0, 20.6, 21.4, 19.9, 19.9, 20.5, 19.1, 19.6, 17.0, 16.3, 16.5, 16.6, 16.1, 16.2, 15.8, 15.9]
# Numbers for the nomask data line y-axis RIGHT SIDE
count_nomask = [9.8, 9.2, 9.5, 9.8, 9.9, 9.6, 9.6, 9.1, 8.4, 8.4, 8.5, 8.4, 9.8, 9.9, 10.1, 9.6, 9.6, 9.7, 10.0, 8.9, 9.1, 8.9, 9.2]

DF = pd.DataFrame()
DF['Date']=date
DF['count_mask']=count_mask
DF['count_nomask']=count_nomask
DF
# Out:
#          Date  count_mask  count_nomask
# 0   7/12/2020        25.3           9.8
# 1   7/13/2020        19.7           9.2
# 2   7/14/2020        19.6           9.5
# 3   7/15/2020        20.5           9.8
# 4   7/16/2020        19.8           9.9
# 5   7/17/2020        19.8           9.6
# 6   7/18/2020        20.5           9.6
# 7   7/19/2020        20.0           9.1
# 8   7/20/2020        20.6           8.4
# 9   7/21/2020        21.4           8.4
# 10  7/22/2020        19.9           8.5
# 11  7/23/2020        19.9           8.4
# 12  7/24/2020        20.5           9.8
# 13  7/25/2020        19.1           9.9
# 14  7/26/2020        19.6          10.1
# 15  7/27/2020        17.0           9.6
# 16  7/28/2020        16.3           9.6
# 17  7/29/2020        16.5           9.7
# 18  7/30/2020        16.6          10.0
# 19  7/31/2020        16.1           8.9
# 20   8/1/2020        16.2           9.1
# 21   8/2/2020        15.8           8.9
# ...

# %% [markdown]
# 3. Make a visualization of this data that is more accurate. Your visualization should more honestly tell the story.
#
#                fig = pd.line(DF,x= ,y= )

# %%
fig = px.line(DF, x='Date', y=['count_mask', 'count_nomask'])
fig.update_layout(yaxis=dict(title=dict(text='Covid Cases')))
fig.show()

# %% [markdown]
# 4. What message is more clear in your visualization, compared to the one posted on twitter?

# %% [markdown]
# The distinction between the two lines is more clear in my visualization compared to the one posted on twitter.

# %% [markdown]
# 5. What, if any, useful information do these data and your visualization tell us about mask wearing and COVID? It’ll be difficult to set aside what you already know about mask wearing, but you should try to focus only on what this visualization tells. Feel free to also comment on whether that lines up with what you know about mask wearing.

# %% [markdown]
# The data demonstrates a significant difference in the number of covid cases in mask-mandated and non-mask mandated counties.

# %% [markdown]
# 6. Could there be confounding data? What can you actually say about the data as given?

# %% [markdown]
# There could be many reasons for the data, for example, the likelihood for a county that already has high covid cases to require masks as a method of damage control rather than prevention. The data does show a pretty clear distinction in the number of people with covid per 100,000, signaling a stronger concentration of people with covid in mask-mandated counties.
