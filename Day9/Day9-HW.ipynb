# %% [markdown]
# ## Introduction to Data Science
#
# #### University of Redlands - DATA 101
# #### Prof: Joanna Bieri [joanna_bieri@redlands.edu](mailto:joanna_bieri@redlands.edu)
# #### [Class Website: data101.joannabieri.com](https://joannabieri.com/data101.html)
#
# ---------------------------------------
# # Homework Day 9
# ---------------------------------------
#
# GOALS:
#
# 1. Import a messy DataFrame and fix it
# 2. Try a pivot
# 3. Play around with more advanced graphing and plotting
#
# ----------------------------------------------------------
#
# This homework has **5 questions** and **2 exercises**.
#
# NOTE: Be kind to yourself. Working with data can be hard! Every data set is different. **Seriously** come get help! Come to lab!

# %% [markdown]
# ## Important Information
#
# - Email: [joanna_bieri@redlands.edu](mailto:joanna_bieri@redlands.edu)
# - Office Hours: Duke 209 <a href="https://joannabieri.com/schedule.html"> Click Here for Joanna's Schedule</a>
#
#
# ## Announcements
#
# **Next week - Data Ethics** You should have some resources (book or 3-4 articles) about some area of data science ethics/impacts.
#
# ## Day 9 Assignment - same drill.
#
# 1. Make sure **Pull** any new content from the class repo - then **Copy** it over into your working diretory.
# 2. Open the file Day3-HW.ipynb and start doing the problems.
#     * You can do these problems as you follow along with the lecture notes and video.
# 3. Get as far as you can before class.
# 4. Submit what you have so far **Commit** and **Push** to Git.
# 5. Take the daily check in quiz on **Canvas**.
# 7. Come to class with lots of questions!

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.io as pio

# %%
pio.renderers.defaule = 'colab'

from itables import show

# %% [markdown]
# ## Data Science Visualization - from start to finish
#
# Today we will do a fill analysis where we will import data, do some data cleaning (recoding), and then walk through how to create a really beautiful visualization.
#
# Survey of religious traditions and income.
#
# Source: [pewforum.org/religious-landscape-study/income-distribution](https://www.pewforum.org/religious-landscape-study/income-distribution/), Retrieved 14 April, 2020
#
# This data is saved in a .xlsx file that is in the data folder that you downloaded.
#
# **You only need to do this once - you can delete the cell below once it runs** To use pd.read_excel() we need to download the openpyxl package:

# %%
# !conda install -y openpyxl
# Out:
# Jupyter detected...
# 3 channel Terms of Service accepted
# Retrieving notices: done
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: C:\Users\garrr\anaconda3
#
#   added / updated specs:
#     - openpyxl
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.11.12 |       h4c7d964_0         149 KB  conda-forge
#     openssl-3.6.0              |       h725018a_0         9.0 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         9.1 MB
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2025.10.5-h4c7d964_0 --> 2025.11.12-h4c7d964_0
#   openssl                                  3.5.4-h725018a_0 --> 3.6.0-h725018a_0
#
#
#
# Downloading and Extracting Packages: ...working...
# openssl-3.6.0        | 9.0 MB    |            |   0%
#
# ca-certificates-2025 | 149 KB    |            |   0%
# openssl-3.6.0        | 9.0 MB    |            |   0%
#
# ca-certificates-2025 | 149 KB    | #          |  11%
# openssl-3.6.0        | 9.0 MB    | #6         |  17%
#
# ca-certificates-2025 | 149 KB    | ########## | 100%
#
# ca-certificates-2025 | 149 KB    | ########## | 100%
#
# ca-certificates-2025 | 149 KB    | ########## | 100%
# openssl-3.6.0        | 9.0 MB    | ###9       |  40%
# openssl-3.6.0        | 9.0 MB    | #####5     |  55%
# openssl-3.6.0        | 9.0 MB    | ########   |  80%
# openssl-3.6.0        | 9.0 MB    | ########## | 100%
# openssl-3.6.0        | 9.0 MB    | ########## | 100%
# openssl-3.6.0        | 9.0 MB    | ########## | 100%
#
#
#
#                                                       done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.7.0
#     latest version: 25.9.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda

# %%
file_name = 'data/relig-income.xlsx'
DF = pd.read_excel(file_name)

# %%
show(DF)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_b3e7a2d8_05cf_4986_8dd9_1b45d5505ce6"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.5.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_b3e7a2d8_05cf_4986_8dd9_1b45d5505ce6:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "text_in_header_can_be_selected": true, "order": [], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "classes": ["display", "nowrap"], "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>Religious tradition</th>\n      <th>Less than $30,000</th>\n      <th>$30,000-$49,999</th>\n      <th>$50,000-$99,999</th>\n      <th>$100,000 or more</th>\n      <th>Sample Size</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"Buddhist\", 0.36, 0.18, 0.32, 0.13, 233], [\"Catholic\", 0.36, 0.19, 0.26, 0.19, 6137], [\"Evangelical Protestant\", 0.35, 0.22, 0.28, 0.14, 7462], [\"Hindu\", 0.17, 0.13, 0.34, 0.36, 172], [\"Historically Black Protestant\", 0.53, 0.22, 0.17, 0.08, 1704], [\"Jehovah's Witness\", 0.48, 0.25, 0.22, 0.04, 208], [\"Jewish\", 0.16, 0.15, 0.24, 0.44, 708], [\"Mainline Protestant\", 0.29, 0.2, 0.28, 0.23, 5208], [\"Mormon\", 0.27, 0.2, 0.33, 0.2, 594], [\"Muslim\", 0.34, 0.17, 0.29, 0.2, 205], [\"Orthodox Christian\", 0.18, 0.17, 0.36, 0.29, 155], [\"Unaffiliated (religious \\\"nones\\\")\", 0.33, 0.2, 0.26, 0.21, 6790]]"};
#         new ITable(table, dt_args);
#     });
# </script>

# %% [markdown]
# **Q1** Describe the data you see here. How many variables and observations. What are the data types? What are the units?

# %% [markdown]
# There are 6 variables and 12 observations. The data contains the religious tradition, the percentage of that demographic that is under each income bracket, and the sample size of that religion.

# %% [markdown]
# **Q2** Following along with the lecture, say in words what each section of the code below does:
#
# **(Click here to answer each one)**
#
# * Section 1 - Renames the variables.
# * Section 2 - Rearranges the table to individuakky store each percentile while keeping the other data and sorts it
# * Section 3 - Adds an extra column with the number of people meeting the criteria
# * Section 4 - Removes the '$' from the income line
# * Section 5 - Sets the number on the left to each observation's current position, and adds a new column called 'index' with the previous index
# * Section 6 - Changes the name of the unaffiliated group
# * Section 7 - Changes the name of the historically black protestant group
# * Section 8 - Changes the name of the evangelical protestant group

# %%
# Section 1
DF.rename(columns={ 'Religious tradition':'religion' ,'Sample Size' : 'n' },inplace=True)
# Section 2
DF_new = pd.melt(DF, id_vars=['religion','n'], var_name='income', value_name='proportion').sort_values('religion')
# Section 3
DF_new['frequency']=np.round(DF_new['proportion']*DF_new['n'])
# Section 4
DF_new['income']=DF_new['income'].apply(lambda x: str(x).replace('$',''))
# Section 5
DF_new.reset_index(inplace=True)

# Section 6
name_to_change = 'Unaffiliated (religious "nones")'
new_name = 'Unaffiliated'
DF_new['religion']=DF_new['religion'].replace(name_to_change,new_name)

# Section 7
name_to_change =  'Historically Black Protestant'
new_name = 'Hist. Black Protestant'
DF_new['religion']=DF_new['religion'].replace(name_to_change,new_name)

# Section 8
name_to_change = 'Evangelical Protestant'
new_name = 'Ev. Protestant'
DF_new['religion']=DF_new['religion'].replace(name_to_change,new_name)

DF_new
# Out:
#     index                religion     n            income  proportion  \
# 0       0                Buddhist   233  Less than 30,000        0.36
# 1      24                Buddhist   233     50,000-99,999        0.32
# 2      36                Buddhist   233   100,000 or more        0.13
# 3      12                Buddhist   233     30,000-49,999        0.18
# 4       1                Catholic  6137  Less than 30,000        0.36
# 5      25                Catholic  6137     50,000-99,999        0.26
# 6      13                Catholic  6137     30,000-49,999        0.19
# 7      37                Catholic  6137   100,000 or more        0.19
# 8      26          Ev. Protestant  7462     50,000-99,999        0.28
# 9      38          Ev. Protestant  7462   100,000 or more        0.14
# 10     14          Ev. Protestant  7462     30,000-49,999        0.22
# 11      2          Ev. Protestant  7462  Less than 30,000        0.35
# 12      3                   Hindu   172  Less than 30,000        0.17
# 13     27                   Hindu   172     50,000-99,999        0.34
# 14     15                   Hindu   172     30,000-49,999        0.13
# 15     39                   Hindu   172   100,000 or more        0.36
# 16     40  Hist. Black Protestant  1704   100,000 or more        0.08
# 17      4  Hist. Black Protestant  1704  Less than 30,000        0.53
# 18     28  Hist. Black Protestant  1704     50,000-99,999        0.17
# 19     16  Hist. Black Protestant  1704     30,000-49,999        0.22
# 20     17       Jehovah's Witness   208     30,000-49,999        0.25
# 21     29       Jehovah's Witness   208     50,000-99,999        0.22
# 22     41       Jehovah's Witness   208   100,000 or more        0.04
# 23      5       Jehovah's Witness   208  Less than 30,000        0.48
# 24     42                  Jewish   708   100,000 or more        0.44
# 25     30                  Jewish   708     50,000-99,999        0.24
# 26      6                  Jewish   708  Less than 30,000        0.16
# 27     18                  Jewish   708     30,000-49,999        0.15
# 28     31     Mainline Protestant  5208     50,000-99,999        0.28
# 29     43     Mainline Protestant  5208   100,000 or more        0.23
# 30     19     Mainline Protestant  5208     30,000-49,999        0.20
# 31      7     Mainline Protestant  5208  Less than 30,000        0.29
# 32     20                  Mormon   594     30,000-49,999        0.20
# 33     32                  Mormon   594     50,000-99,999        0.33
# 34     44                  Mormon   594   100,000 or more        0.20
# 35      8                  Mormon   594  Less than 30,000        0.27
# 36     33                  Muslim   205     50,000-99,999        0.29
# 37     45                  Muslim   205   100,000 or more        0.20
# 38      9                  Muslim   205  Less than 30,000        0.34
# 39     21                  Muslim   205     30,000-49,999        0.17
# 40     22      Orthodox Christian   155     30,000-49,999        0.17
# 41     34      Orthodox Christian   155     50,000-99,999        0.36
# 42     10      Orthodox Christian   155  Less than 30,000        0.18
# 43     46      Orthodox Christian   155   100,000 or more        0.29
# 44     23            Unaffiliated  6790     30,000-49,999        0.20
# 45     11            Unaffiliated  6790  Less than 30,000        0.33
# 46     35            Unaffiliated  6790     50,000-99,999        0.26
# 47     47            Unaffiliated  6790   100,000 or more        0.21
#
#     frequency
# 0        84.0
# 1        75.0
# 2        30.0
# 3        42.0
# 4      2209.0
# 5      1596.0
# 6      1166.0
# 7      1166.0
# 8      2089.0
# 9      1045.0
# 10     1642.0
# 11     2612.0
# 12       29.0
# 13       58.0
# 14       22.0
# 15       62.0
# 16      136.0
# 17      903.0
# 18      290.0
# 19      375.0
# 20       52.0
# 21       46.0
# 22        8.0
# 23      100.0
# 24      312.0
# 25      170.0
# 26      113.0
# 27      106.0
# 28     1458.0
# 29     1198.0
# 30     1042.0
# 31     1510.0
# 32      119.0
# 33      196.0
# 34      119.0
# 35      160.0
# 36       59.0
# 37       41.0
# 38       70.0
# 39       35.0
# 40       26.0
# 41       56.0
# 42       28.0
# 43       45.0
# 44     1358.0
# 45     2241.0
# 46     1765.0
# 47     1426.0

# %% [markdown]
# ## Make a Bar Plot

# %% [markdown]
# ## There are SO MANY CUSTOMIZATION OPTIONS!
#
# You are not expected to have all of these options memorized. You should just know that these things are possible and then look up examples for how to do fancier things. I always start simple and then add on from there.
#
# ## Final Plot

# %%
fig = px.bar(DF_new,
             y='religion',
             x='proportion',
             color='income',
             color_discrete_sequence=px.colors.qualitative.Vivid,
             category_orders={'income' : ['Less than 30,000', '30,000-49,999', '50,000-99,999', '100,000 or more']})

fig.update_layout(template="plotly_white",
                  title='Income Distribution by religious group <br><sup>Data Source: Pew Research Center, Religious Lansdcape Study</sup>',
                  title_x=0.5,
                  yaxis={'categoryorder': 'category descending'},
                  xaxis_title="Proportion",
                  yaxis_title="",
                  legend_title='Income',
                  legend={'orientation':"h",'yanchor':"bottom",'y':-0.2, 'xanchor':"right",'x':1.05},
                  font={'family':"Courier New, monospace",'size':16,'color':"Darkblue"},
                  autosize=False,
                  width=1000,
                  height=800)

fig.show()

# %% [markdown]
# ## Exercise 1
#
# Make your own version of the plot above. Here are some changes you should try:
#
# * Change the font family - some common fonts to try:
#
#         ["Arial",
#         "Balto",
#         "Courier New",
#         "Droid Sans",
#         "Droid Serif",
#         "Droid Sans Mono",
#         "Gravitas One",
#         "Old Standard TT",
#         "Open Sans",
#         "Overpass",
#         "PT Sans Narrow",
#         "Raleway",
#         "Times New Roman"]
#
# * Move the legend to somewhere else.
#
# * Change the template and the color.
#
# * Advanced - look up how you can change the pattern_shape or pattern_shape_sequence.

# %%
newfig = px.bar(DF_new,
             y='religion',
             x='proportion',
             color='income',
             color_discrete_sequence=px.colors.qualitative.Safe,
             category_orders={'income' : ['Less than 30,000', '30,000-49,999', '50,000-99,999', '100,000 or more']},
             pattern_shape='income',
             pattern_shape_sequence=['/', '+', '\\', 'x'])

newfig.update_layout(template="seaborn",
                  title='Income Distribution by religious group <br><sup>Data Source: Pew Research Center, Religious Lansdcape Study</sup>',
                  title_x=0.5,
                  yaxis={'categoryorder': 'category descending'},
                  xaxis_title="Proportion",
                  yaxis_title="",
                  legend_title='Income',
                  legend={'orientation':"h",'yanchor':"bottom",'y':0.975, 'xanchor':"right",'x':0.95},
                  font={'family':"Comic Sans, monospace",'size':16,'color':"Darkblue"},
                  autosize=False,
                  width=1000,
                  height=800)

newfig.show()

# %% [markdown]
# ## Exercise 2
#
# In this exercise we are going to import some very messy data and see how we can Recode, Tidy, and Pivot the data!
#
# ### 1. Import the data from the file: file_name = 'data/sales.xlsx'
#
# Look at the DataFrame, the data is not in a great format. Why is this data not tidy? List a few reasons that this data has problems.

# %%
# Your code here
DF_sales = pd.read_excel('data/sales.xlsx')
show(DF_sales)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_a5f7a286_b525_44b7_b399_317366c2ee30"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.5.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_a5f7a286_b525_44b7_b399_317366c2ee30:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "text_in_header_can_be_selected": true, "order": [], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "classes": ["display", "nowrap"], "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>This file contains information on sales.</th>\n      <th>Unnamed: 1</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"Data are organized by brand name, and for each brand we have the ID number for item sold, and how many are sold.\", \"NaN\"], [\"NaN\", \"NaN\"], [\"NaN\", \"NaN\"], [\"Brand 1\", \"n\"], [\"1234\", \"8\"], [\"8721\", \"2\"], [\"1822\", \"3\"], [\"Brand 2\", \"n\"], [\"3333\", \"1\"], [\"2156\", \"3\"], [\"3987\", \"6\"], [\"3216\", \"5\"]]"};
#         new ITable(table, dt_args);
#     });
# </script>

# %% [markdown]
# The variables don't seem to be named right, and the data has a lot of NaNs. The number of variables seems to be wrong as well.

# %% [markdown]
# This is what you should see:
#
# ![DataFrame1](images/DF1.png)
#
#
# ### 2. Now we need to fix this data - when we read this in there are some weird things happening.
#
# Open the .sales.xlsx file and look in there. Notice that there are two weird rows at the top.
#
# How can we read the data in and skip some rows? Try running the command below to read the documentation. Are there any commands that might help us skip the first three rows when reading in the data?

# %%
DF_sales = pd.read_excel('data/sales.xlsx', skiprows=3)
show(DF_sales)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_a7bcb6dc_065e_46ec_b4b2_b537b4c894cb"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.5.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_a7bcb6dc_065e_46ec_b4b2_b537b4c894cb:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "text_in_header_can_be_selected": true, "order": [], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "classes": ["display", "nowrap"], "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>Unnamed: 0</th>\n      <th>Unnamed: 1</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"Brand 1\", \"n\"], [\"1234\", \"8\"], [\"8721\", \"2\"], [\"1822\", \"3\"], [\"Brand 2\", \"n\"], [\"3333\", \"1\"], [\"2156\", \"3\"], [\"3987\", \"6\"], [\"3216\", \"5\"]]"};
#         new ITable(table, dt_args);
#     });
# </script>

# %% [markdown]
# Try writing your own code that will read in the data, skipping three rows, so that it looks like this:
#
# ![DataFrame2](images/DF2.png)

# %% [markdown]
# ### 3. This is better, but let's rename the columns
#
# In the lecture above we learned how to rename columns. Rename the columns in this DataFrame so that 'Unnamed: 0' becomes 'id' and 'Unnamed: 1' becomes 'n'. Your DataFrame should look like
#
# ![DataFrame3](images/DF3.png)

# %%
DF_sales.rename(columns={'Unnamed: 0':'id', 'Unnamed: 1' : 'n'},inplace=True)
show(DF_sales)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_efdab9fc_3195_49a4_92e5_07812ccb99c0"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.5.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_efdab9fc_3195_49a4_92e5_07812ccb99c0:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "text_in_header_can_be_selected": true, "order": [], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "classes": ["display", "nowrap"], "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>id</th>\n      <th>n</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"Brand 1\", \"n\"], [\"1234\", \"8\"], [\"8721\", \"2\"], [\"1822\", \"3\"], [\"Brand 2\", \"n\"], [\"3333\", \"1\"], [\"2156\", \"3\"], [\"3987\", \"6\"], [\"3216\", \"5\"]]"};
#         new ITable(table, dt_args);
#     });
# </script>

# %% [markdown]
# ### 4. This is better, but....
#
# This is not yet a tidy data frame. Why not?

# %% [markdown]
# The data isn't sorted by it's true observations (the brands)

# %% [markdown]
# **How do we make it tidy?**
#
# We need to manipulate the data so that we have three columns. The brand, the id, and then the number of sales, but the brand information is mixed up in the id row. We are going to use the following command:
#
#     brand_data = DF['id'].apply(lambda x: x if 'Brand' in str(x) else np.nan)
#
# Tell me what each part of this command does. For example break down each piece:
#
# a. DF['id']
#
# b. .apply()
#
# c. lambda x: x if 'Brand' in str(x) else np.nan
#
# HINT1 - here you see something new and if else statement.
#
# - The command **'Brand' in str(x)** will check to see if the word 'Brand' is in each row. This will return True or False.
# - To test this try **DF['id'].apply(lambda x: 'Brand' in str(x))** in a separate cell.
# - The **if** statement checks to see if **'Brand' in str(x)** is True. If it is true it returns the x (original data). Otherwise it returns **np.nan**
# - **np.nan** is how we can get Not a Number.

# %% [markdown]
# a) DF['id'] selects the id column only \
# b) .apply() applies the function inside the parentheses to the data \
# c) lambda c: x if 'Brand' in str(x) else np.nan sets the value of the data to null if it doesn't contain the word 'Brand' in it

# %%
# Now just run the command
brand_data = DF_sales['id'].apply(lambda x: x if 'Brand' in str(x) else np.nan)
brand_data
# Out:
# 0    Brand 1
# 1        NaN
# 2        NaN
# 3        NaN
# 4    Brand 2
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# Name: id, dtype: object

# %% [markdown]
# ### 5. Create a new empty column to store our brand_data
#
# You should know how to add a new column to a data frame. Use the column name 'brand'.

# %%
DF_sales['brand'] = brand_data
show(DF_sales)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_ef30e071_4d6d_4bee_a775_6ee26dc0e9a7"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.5.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_ef30e071_4d6d_4bee_a775_6ee26dc0e9a7:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "text_in_header_can_be_selected": true, "order": [], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "classes": ["display", "nowrap"], "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>id</th>\n      <th>n</th>\n      <th>brand</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"Brand 1\", \"n\", \"Brand 1\"], [\"1234\", \"8\", \"NaN\"], [\"8721\", \"2\", \"NaN\"], [\"1822\", \"3\", \"NaN\"], [\"Brand 2\", \"n\", \"Brand 2\"], [\"3333\", \"1\", \"NaN\"], [\"2156\", \"3\", \"NaN\"], [\"3987\", \"6\", \"NaN\"], [\"3216\", \"5\", \"NaN\"]]"};
#         new ITable(table, dt_args);
#     });
# </script>

# %% [markdown]
# ### 6. Lets fill up those NaNs with the brand information
#
# The command **.ffill()** works like magic! It goes down the column and will fill any NaNs with the information from the cells above, until it gets to another good value. Check out what this command does!
#
# ```{python}
# DF=DF.ffill()
# ```
#
# Your data frame should look like
#
# ![DataFrame4](images/DF4.png)

# %%
DF_sales = DF_sales.ffill()
show(DF_sales)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_f050d730_1818_46c3_aa4c_96dad172c4eb"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.5.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_f050d730_1818_46c3_aa4c_96dad172c4eb:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "text_in_header_can_be_selected": true, "order": [], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "classes": ["display", "nowrap"], "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>id</th>\n      <th>n</th>\n      <th>brand</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"Brand 1\", \"n\", \"Brand 1\"], [\"1234\", \"8\", \"Brand 1\"], [\"8721\", \"2\", \"Brand 1\"], [\"1822\", \"3\", \"Brand 1\"], [\"Brand 2\", \"n\", \"Brand 2\"], [\"3333\", \"1\", \"Brand 2\"], [\"2156\", \"3\", \"Brand 2\"], [\"3987\", \"6\", \"Brand 2\"], [\"3216\", \"5\", \"Brand 2\"]]"};
#         new ITable(table, dt_args);
#     });
# </script>

# %% [markdown]
# ### 7. Finally mask out the rows that have bad 'id'
#
# Create a mask using
#
#     mask = DF['id'].apply(lambda x:'Brand' not in str(x) )
#
# then apply that mask to get
#
# ![DataFrame5](images/DF5.png)

# %%
DF_sales = DF_sales[DF_sales['id'].apply(lambda x: 'Brand' not in str(x))]
show(DF_sales)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_ee40b33a_30b1_43cb_95e1_0a369df9182a"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.5.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_ee40b33a_30b1_43cb_95e1_0a369df9182a:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "text_in_header_can_be_selected": true, "order": [], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "classes": ["display", "nowrap"], "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>id</th>\n      <th>n</th>\n      <th>brand</th>\n    </tr>\n  </thead></table>", "data_json": "[[1, \"1234\", \"8\", \"Brand 1\"], [2, \"8721\", \"2\", \"Brand 1\"], [3, \"1822\", \"3\", \"Brand 1\"], [5, \"3333\", \"1\", \"Brand 2\"], [6, \"2156\", \"3\", \"Brand 2\"], [7, \"3987\", \"6\", \"Brand 2\"], [8, \"3216\", \"5\", \"Brand 2\"]]"};
#         new ITable(table, dt_args);
#     });
# </script>

# %% [markdown]
# ### 7. Now lets pivot!!
#
# Try out the **.pivot()** command. See if you can create a DataFrame that looks like this:
#
# ![DataFrame6](images/DF6.png)
#
#     DF_new.pivot(index=???, columns=???,values=???)
#
#
# This is hard! The lecture notes have hints and answers!

# %%
DF_new = DF_sales.pivot(columns='brand', index='id', values='n')
show(DF_new)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_5f7002ff_9536_48d7_80a5_ab7a09ab57dd"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.5.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_5f7002ff_9536_48d7_80a5_ab7a09ab57dd:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "text_in_header_can_be_selected": true, "order": [], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "classes": ["display", "nowrap"], "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th>brand</th>\n      <th>Brand 1</th>\n      <th>Brand 2</th>\n    </tr>\n    <tr>\n      <th>id</th>\n      <th></th>\n      <th></th>\n    </tr>\n  </thead></table>", "data_json": "[[1234, \"8\", \"NaN\"], [1822, \"3\", \"NaN\"], [2156, \"NaN\", \"3\"], [3216, \"NaN\", \"5\"], [3333, \"NaN\", \"1\"], [3987, \"NaN\", \"6\"], [8721, \"2\", \"NaN\"]]"};
#         new ITable(table, dt_args);
#     });
# </script>

# %%
DF_new = DF_new.fillna(0)
show(DF_new)
# Out:
# C:\Users\garrr\AppData\Local\Temp\ipykernel_31188\1909830838.py:1: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# <!--| quarto-html-table-processing: none -->
# <table id="itables_31038754_074f_4653_b65b_57b1bab98ef8"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.5.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_31038754_074f_4653_b65b_57b1bab98ef8:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "text_in_header_can_be_selected": true, "order": [], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "classes": ["display", "nowrap"], "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th>brand</th>\n      <th>Brand 1</th>\n      <th>Brand 2</th>\n    </tr>\n    <tr>\n      <th>id</th>\n      <th></th>\n      <th></th>\n    </tr>\n  </thead></table>", "data_json": "[[1234, 8, 0], [1822, 3, 0], [2156, 0, 3], [3216, 0, 5], [3333, 0, 1], [3987, 0, 6], [8721, 2, 0]]"};
#         new ITable(table, dt_args);
#     });
# </script>
